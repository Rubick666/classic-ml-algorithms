# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import random

# %% [raw]
# np.random.seed(0)

# %%
x, y = make_blobs(n_samples=5000, centers=[[4, 4], [-2, -1], [2, -3], [1, 1]], cluster_std=0.9)
print(x)
print("**********************")
print(y)
# Out:
# [[ 1.48219629  0.35603174]
#  [-0.76906414 -0.04234919]
#  [ 2.94581494  0.51395109]
#  ...
#  [ 4.59978356  2.07297664]
#  [ 0.87258086  1.25191091]
#  [ 2.55953939 -2.46570269]]
# **********************
# [3 1 3 ... 0 3 2]

# %%
plt.scatter(x[:, 0], x[:, 1], marker='.')

# %%
from sklearn.cluster import KMeans
k_means = KMeans(init='k-means++', n_clusters=4, n_init=12)

# %%
k_means.fit(x)
# Out:
# KMeans(n_clusters=4, n_init=12)

# %%
k_means_labels = k_means.labels_
k_means_labels
# Out:
# array([1, 3, 1, ..., 2, 1, 0])

# %%
k_means_cluster_centers = k_means.cluster_centers_
k_means_cluster_centers
# Out:
# array([[ 2.03784995, -3.01049366],
#        [ 1.05776795,  0.99488109],
#        [ 4.01941995,  3.99843123],
#        [-2.01848434, -0.98018883]])

# %%
k_means.n_iter_
# Out:
# 4
